# %% [markdown]
# # Delivery Duration Prediction

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Loading Dataset

# %%
df = pd.read_csv(r'https://raw.githubusercontent.com/akash-ostwal/Machine-Learning/refs/heads/main/Project1-Regression_Delivery_Duration_Prediction/Historical_Dataset.csv')

# %%
df.head()
# Out:
#    market_id created_at actual_delivery_time  store_id store_primary_category  \
# 0        1.0   22:24:17             23:27:16      1845               american
# 1        2.0   21:49:25             22:56:29      5477                mexican
# 2        3.0   20:39:28             21:09:09      5477                    NaN
# 3        3.0   21:21:45             22:13:00      5477                    NaN
# 4        3.0    2:40:36              3:20:26      5477                    NaN
#
#    order_protocol  total_items  subtotal  num_distinct_items  min_item_price  \
# 0             1.0            4      3441                   4             557
# 1             2.0            1      1900                   1            1400
# 2             1.0            1      1900                   1            1900
# 3             1.0            6      6900                   5             600
# 4             1.0            3      3900                   3            1100
#
#    max_item_price  total_onshift_dashers  total_busy_dashers  \
# 0            1239                   33.0                14.0
# 1            1400                    1.0                 2.0
# 2            1900                    1.0                 0.0
# 3            1800                    1.0                 1.0
# 4            1600                    6.0                 6.0
#
#    total_outstanding_orders  estimated_order_place_duration  \
# 0                      21.0                             446
# 1                       2.0                             446
# 2                       0.0                             446
# 3                       2.0                             446
# 4                       9.0                             446
#
#    estimated_store_to_consumer_driving_duration
# 0                                         861.0
# 1                                         690.0
# 2                                         690.0
# 3                                         289.0
# 4                                         650.0

# %%
df.columns = df.columns.str.upper()
df.columns
# Out:
# Index(['MARKET_ID', 'CREATED_AT', 'ACTUAL_DELIVERY_TIME', 'STORE_ID',
#        'STORE_PRIMARY_CATEGORY', 'ORDER_PROTOCOL', 'TOTAL_ITEMS', 'SUBTOTAL',
#        'NUM_DISTINCT_ITEMS', 'MIN_ITEM_PRICE', 'MAX_ITEM_PRICE',
#        'TOTAL_ONSHIFT_DASHERS', 'TOTAL_BUSY_DASHERS',
#        'TOTAL_OUTSTANDING_ORDERS', 'ESTIMATED_ORDER_PLACE_DURATION',
#        'ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION'],
#       dtype='object')

# %% [markdown]
# ### Data quality checks

# %%
df.shape
# Out:
# (197428, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197428 entries, 0 to 197427
# Data columns (total 16 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   MARKET_ID                                     196441 non-null  float64
#  1   CREATED_AT                                    197428 non-null  object
#  2   ACTUAL_DELIVERY_TIME                          197421 non-null  object
#  3   STORE_ID                                      197428 non-null  int64
#  4   STORE_PRIMARY_CATEGORY                        192668 non-null  object
#  5   ORDER_PROTOCOL                                196433 non-null  float64
#  6   TOTAL_ITEMS                                   197428 non-null  int64
#  7   SUBTOTAL                                      197428 non-null  int64
#  8   NUM_DISTINCT_ITEMS                            197428 non-null  int64
#  9   MIN_ITEM_PRICE                                197428 non-null  int64
#  10  MAX_ITEM_PRICE                                197428 non-null  int64
#  11  TOTAL_ONSHIFT_DASHERS                         181166 non-null  float64
#  12  TOTAL_BUSY_DASHERS                            181166 non-null  float64
#  13  TOTAL_OUTSTANDING_ORDERS                      181166 non-null  float64
#  14  ESTIMATED_ORDER_PLACE_DURATION                197428 non-null  int64
#  15  ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION  196902 non-null  float64
# dtypes: float64(6), int64(7), object(3)
# memory usage: 24.1+ MB

# %%
# Checking duplicated data
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates()

# %%
# Checking missing data
missing_counts = df.isna().sum()
missing_percentage = (missing_counts/df.shape[0]*100).round(2)

# %%
missing_summary = pd.DataFrame({
    "missing_counts": missing_counts,
    "missing_percentage": missing_percentage
})
missing_summary
# Out:
#                                               missing_counts  \
# MARKET_ID                                                987
# CREATED_AT                                                 0
# ACTUAL_DELIVERY_TIME                                       7
# STORE_ID                                                   0
# STORE_PRIMARY_CATEGORY                                  4760
# ORDER_PROTOCOL                                           995
# TOTAL_ITEMS                                                0
# SUBTOTAL                                                   0
# NUM_DISTINCT_ITEMS                                         0
# MIN_ITEM_PRICE                                             0
# MAX_ITEM_PRICE                                             0
# TOTAL_ONSHIFT_DASHERS                                  16262
# TOTAL_BUSY_DASHERS                                     16262
# TOTAL_OUTSTANDING_ORDERS                               16262
# ESTIMATED_ORDER_PLACE_DURATION                             0
# ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION             526
#
#                                               missing_percentage
# MARKET_ID                                                   0.50
# CREATED_AT                                                  0.00
# ACTUAL_DELIVERY_TIME                                        0.00
# STORE_ID                                                    0.00
# STORE_PRIMARY_CATEGORY                                      2.41
# ORDER_PROTOCOL                                              0.50
# TOTAL_ITEMS                                                 0.00
# SUBTOTAL                                                    0.00
# NUM_DISTINCT_ITEMS                                          0.00
# MIN_ITEM_PRICE                                              0.00
# MAX_ITEM_PRICE                                              0.00
# TOTAL_ONSHIFT_DASHERS                                       8.24
# TOTAL_BUSY_DASHERS                                          8.24
# TOTAL_OUTSTANDING_ORDERS                                    8.24
# ESTIMATED_ORDER_PLACE_DURATION                              0.00
# ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION                0.27

# %%
# For now we are droping the missing data which is below 0.5
df = df.dropna(subset=['MARKET_ID','ACTUAL_DELIVERY_TIME','ORDER_PROTOCOL','ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION'])

# %%
df.isna().sum()
# Out:
# MARKET_ID                                           0
# CREATED_AT                                          0
# ACTUAL_DELIVERY_TIME                                0
# STORE_ID                                            0
# STORE_PRIMARY_CATEGORY                           3995
# ORDER_PROTOCOL                                      0
# TOTAL_ITEMS                                         0
# SUBTOTAL                                            0
# NUM_DISTINCT_ITEMS                                  0
# MIN_ITEM_PRICE                                      0
# MAX_ITEM_PRICE                                      0
# TOTAL_ONSHIFT_DASHERS                           16107
# TOTAL_BUSY_DASHERS                              16107
# TOTAL_OUTSTANDING_ORDERS                        16107
# ESTIMATED_ORDER_PLACE_DURATION                      0
# ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION        0
# dtype: int64

# %%
# Converring data type of CREATED_AT & ACTUAL_DELIVERY_TIME columns.
df['CREATED_AT'] = pd.to_timedelta(df['CREATED_AT'])
df['ACTUAL_DELIVERY_TIME'] = pd.to_timedelta(df['ACTUAL_DELIVERY_TIME'])

df['DELIVERY_DURATION_SEC'] = (df['ACTUAL_DELIVERY_TIME'] - df['CREATED_AT']).dt.total_seconds()

# %%
df.dtypes
# Out:
# MARKET_ID                                               float64
# CREATED_AT                                      timedelta64[ns]
# ACTUAL_DELIVERY_TIME                            timedelta64[ns]
# STORE_ID                                                  int64
# STORE_PRIMARY_CATEGORY                                   object
# ORDER_PROTOCOL                                          float64
# TOTAL_ITEMS                                               int64
# SUBTOTAL                                                  int64
# NUM_DISTINCT_ITEMS                                        int64
# MIN_ITEM_PRICE                                            int64
# MAX_ITEM_PRICE                                            int64
# TOTAL_ONSHIFT_DASHERS                                   float64
# TOTAL_BUSY_DASHERS                                      float64
# TOTAL_OUTSTANDING_ORDERS                                float64
# ESTIMATED_ORDER_PLACE_DURATION                            int64
# ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION            float64
# DELIVERY_DURATION_SEC                                   float64
# dtype: object

# %%
df.head()
# Out:
#    MARKET_ID      CREATED_AT ACTUAL_DELIVERY_TIME  STORE_ID  \
# 0        1.0 0 days 22:24:17      0 days 23:27:16      1845
# 1        2.0 0 days 21:49:25      0 days 22:56:29      5477
# 2        3.0 0 days 20:39:28      0 days 21:09:09      5477
# 3        3.0 0 days 21:21:45      0 days 22:13:00      5477
# 4        3.0 0 days 02:40:36      0 days 03:20:26      5477
#
#   STORE_PRIMARY_CATEGORY  ORDER_PROTOCOL  TOTAL_ITEMS  SUBTOTAL  \
# 0               american             1.0            4      3441
# 1                mexican             2.0            1      1900
# 2                    NaN             1.0            1      1900
# 3                    NaN             1.0            6      6900
# 4                    NaN             1.0            3      3900
#
#    NUM_DISTINCT_ITEMS  MIN_ITEM_PRICE  MAX_ITEM_PRICE  TOTAL_ONSHIFT_DASHERS  \
# 0                   4             557            1239                   33.0
# 1                   1            1400            1400                    1.0
# 2                   1            1900            1900                    1.0
# 3                   5             600            1800                    1.0
# 4                   3            1100            1600                    6.0
#
#    TOTAL_BUSY_DASHERS  TOTAL_OUTSTANDING_ORDERS  \
# 0                14.0                      21.0
# 1                 2.0                       2.0
# 2                 0.0                       0.0
# 3                 1.0                       2.0
# 4                 6.0                       9.0
#
#    ESTIMATED_ORDER_PLACE_DURATION  \
# 0                             446
# 1                             446
# 2                             446
# 3                             446
# 4                             446
#
#    ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION  DELIVERY_DURATION_SEC
# 0                                         861.0                 3779.0
# 1                                         690.0                 4024.0
# 2                                         690.0                 1781.0
# 3                                         289.0                 3075.0
# 4                                         650.0                 2390.0

# %%
df['CREATED_AT'].mode()
# Out:
# 0   0 days 02:27:40
# Name: CREATED_AT, dtype: timedelta64[ns]

# %%
df['ACTUAL_DELIVERY_TIME'].mode()
# Out:
# 0   0 days 03:27:25
# Name: ACTUAL_DELIVERY_TIME, dtype: timedelta64[ns]

# %% [markdown]
# ### Data Cleaning & Data preprocessing

# %%
# Organizing the dataset into numerical, categorical, and datetime columns.
cat  = df.select_dtypes(include=['object']).columns.tolist()
con_int  = df.select_dtypes(include=['int64']).columns.tolist()
con_float  = df.select_dtypes(include=['float64']).columns.tolist()
time = df.select_dtypes(include=['timedelta64']).columns.tolist()

# %%
print("Categorical:", cat)
print("Numerical:", con_int,con_float,sep='\n')
print("Time:", time)
# Out:
# Categorical: ['STORE_PRIMARY_CATEGORY']
# Numerical:
# ['STORE_ID', 'TOTAL_ITEMS', 'SUBTOTAL', 'NUM_DISTINCT_ITEMS', 'MIN_ITEM_PRICE', 'MAX_ITEM_PRICE', 'ESTIMATED_ORDER_PLACE_DURATION']
# ['MARKET_ID', 'ORDER_PROTOCOL', 'TOTAL_ONSHIFT_DASHERS', 'TOTAL_BUSY_DASHERS', 'TOTAL_OUTSTANDING_ORDERS', 'ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION', 'DELIVERY_DURATION_SEC']
# Time: ['CREATED_AT', 'ACTUAL_DELIVERY_TIME']

# %%
# Import Pipeline
from sklearn.pipeline import make_pipeline
# Import Imputer that performs missing data handling by replacing missing data with central tendency
from sklearn.impute import SimpleImputer
# Column Transformer combines pipelines. Here we have 2 pipelines- categorical and continuous 
from sklearn.compose import ColumnTransformer

# %%
num_pipe = make_pipeline(SimpleImputer(strategy="constant", fill_value=0))
cat_pipe = make_pipeline(SimpleImputer(strategy="constant", fill_value="Unknown"))
time_pipe = 'passthrough'

# %%
# combine both the pipelines
final_pipe = ColumnTransformer(transformers=[
    ('time',time_pipe,time),
    ('cat',cat_pipe,cat),
    ('con_int',num_pipe,con_int),
    ('con_float',num_pipe,con_float)    
]).set_output(transform="pandas")

# %%
final_pipe
# Out:
# ColumnTransformer(transformers=[('time', 'passthrough',
#                                  ['CREATED_AT', 'ACTUAL_DELIVERY_TIME']),
#                                 ('cat',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value='Unknown',
#                                                                 strategy='constant'))]),
#                                  ['STORE_PRIMARY_CATEGORY']),
#                                 ('con_int',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'))]),
#                                  ['STORE_ID', 'TOTAL_ITEMS', 'SUBTOTAL',
#                                   'NUM_DISTINCT_ITEMS', 'MIN_ITEM_PRICE',
#                                   'MAX_ITEM_PRICE',
#                                   'ESTIMATED_ORDER_PLACE_DURATION']),
#                                 ('con_float',
#                                  Pipeline(steps=[('simpleimputer',
#                                                   SimpleImputer(fill_value=0,
#                                                                 strategy='constant'))]),
#                                  ['MARKET_ID', 'ORDER_PROTOCOL',
#                                   'TOTAL_ONSHIFT_DASHERS', 'TOTAL_BUSY_DASHERS',
#                                   'TOTAL_OUTSTANDING_ORDERS',
#                                   'ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION',
#                                   'DELIVERY_DURATION_SEC'])])

# %%
df_cleaned = final_pipe.fit_transform(df)
df_cleaned.head(3)
# Out:
#   time__CREATED_AT time__ACTUAL_DELIVERY_TIME cat__STORE_PRIMARY_CATEGORY  \
# 0  0 days 22:24:17            0 days 23:27:16                    american
# 1  0 days 21:49:25            0 days 22:56:29                     mexican
# 2  0 days 20:39:28            0 days 21:09:09                     Unknown
#
#    con_int__STORE_ID  con_int__TOTAL_ITEMS  con_int__SUBTOTAL  \
# 0               1845                     4               3441
# 1               5477                     1               1900
# 2               5477                     1               1900
#
#    con_int__NUM_DISTINCT_ITEMS  con_int__MIN_ITEM_PRICE  \
# 0                            4                      557
# 1                            1                     1400
# 2                            1                     1900
#
#    con_int__MAX_ITEM_PRICE  con_int__ESTIMATED_ORDER_PLACE_DURATION  \
# 0                     1239                                      446
# 1                     1400                                      446
# 2                     1900                                      446
#
#    con_float__MARKET_ID  con_float__ORDER_PROTOCOL  \
# 0                   1.0                        1.0
# 1                   2.0                        2.0
# 2                   3.0                        1.0
#
#    con_float__TOTAL_ONSHIFT_DASHERS  con_float__TOTAL_BUSY_DASHERS  \
# 0                              33.0                           14.0
# 1                               1.0                            2.0
# 2                               1.0                            0.0
#
#    con_float__TOTAL_OUTSTANDING_ORDERS  \
# 0                                 21.0
# 1                                  2.0
# 2                                  0.0
#
#    con_float__ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION  \
# 0                                              861.0
# 1                                              690.0
# 2                                              690.0
#
#    con_float__DELIVERY_DURATION_SEC
# 0                            3779.0
# 1                            4024.0
# 2                            1781.0

# %%
df_cleaned.isna().sum()
# Out:
# time__CREATED_AT                                           0
# time__ACTUAL_DELIVERY_TIME                                 0
# cat__STORE_PRIMARY_CATEGORY                                0
# con_int__STORE_ID                                          0
# con_int__TOTAL_ITEMS                                       0
# con_int__SUBTOTAL                                          0
# con_int__NUM_DISTINCT_ITEMS                                0
# con_int__MIN_ITEM_PRICE                                    0
# con_int__MAX_ITEM_PRICE                                    0
# con_int__ESTIMATED_ORDER_PLACE_DURATION                    0
# con_float__MARKET_ID                                       0
# con_float__ORDER_PROTOCOL                                  0
# con_float__TOTAL_ONSHIFT_DASHERS                           0
# con_float__TOTAL_BUSY_DASHERS                              0
# con_float__TOTAL_OUTSTANDING_ORDERS                        0
# con_float__ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION    0
# con_float__DELIVERY_DURATION_SEC                           0
# dtype: int64

# %% [markdown]
# **Now there is no missing data**

# %%
new_cols = []
for i in df_cleaned.columns:
    c = i.split('__')[-1]
    new_cols.append(c)
print(new_cols)
# Out:
# ['CREATED_AT', 'ACTUAL_DELIVERY_TIME', 'STORE_PRIMARY_CATEGORY', 'STORE_ID', 'TOTAL_ITEMS', 'SUBTOTAL', 'NUM_DISTINCT_ITEMS', 'MIN_ITEM_PRICE', 'MAX_ITEM_PRICE', 'ESTIMATED_ORDER_PLACE_DURATION', 'MARKET_ID', 'ORDER_PROTOCOL', 'TOTAL_ONSHIFT_DASHERS', 'TOTAL_BUSY_DASHERS', 'TOTAL_OUTSTANDING_ORDERS', 'ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION', 'DELIVERY_DURATION_SEC']

# %%
df_cleaned.columns = new_cols
df_cleaned.columns
# Out:
# Index(['CREATED_AT', 'ACTUAL_DELIVERY_TIME', 'STORE_PRIMARY_CATEGORY',
#        'STORE_ID', 'TOTAL_ITEMS', 'SUBTOTAL', 'NUM_DISTINCT_ITEMS',
#        'MIN_ITEM_PRICE', 'MAX_ITEM_PRICE', 'ESTIMATED_ORDER_PLACE_DURATION',
#        'MARKET_ID', 'ORDER_PROTOCOL', 'TOTAL_ONSHIFT_DASHERS',
#        'TOTAL_BUSY_DASHERS', 'TOTAL_OUTSTANDING_ORDERS',
#        'ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION',
#        'DELIVERY_DURATION_SEC'],
#       dtype='object')

# %%
df_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 195402 entries, 0 to 197427
# Data columns (total 17 columns):
#  #   Column                                        Non-Null Count   Dtype
# ---  ------                                        --------------   -----
#  0   CREATED_AT                                    195402 non-null  timedelta64[ns]
#  1   ACTUAL_DELIVERY_TIME                          195402 non-null  timedelta64[ns]
#  2   STORE_PRIMARY_CATEGORY                        195402 non-null  object
#  3   STORE_ID                                      195402 non-null  int64
#  4   TOTAL_ITEMS                                   195402 non-null  int64
#  5   SUBTOTAL                                      195402 non-null  int64
#  6   NUM_DISTINCT_ITEMS                            195402 non-null  int64
#  7   MIN_ITEM_PRICE                                195402 non-null  int64
#  8   MAX_ITEM_PRICE                                195402 non-null  int64
#  9   ESTIMATED_ORDER_PLACE_DURATION                195402 non-null  int64
#  10  MARKET_ID                                     195402 non-null  float64
#  11  ORDER_PROTOCOL                                195402 non-null  float64
#  12  TOTAL_ONSHIFT_DASHERS                         195402 non-null  float64
#  13  TOTAL_BUSY_DASHERS                            195402 non-null  float64
#  14  TOTAL_OUTSTANDING_ORDERS                      195402 non-null  float64
#  15  ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION  195402 non-null  float64
#  16  DELIVERY_DURATION_SEC                         195402 non-null  float64
# dtypes: float64(7), int64(7), object(1), timedelta64[ns](2)
# memory usage: 26.8+ MB

# %% [markdown]
# ### Outliers Detecting & Handling

# %%
con = con_int + con_float
con
# Out:
# ['STORE_ID',
#  'TOTAL_ITEMS',
#  'SUBTOTAL',
#  'NUM_DISTINCT_ITEMS',
#  'MIN_ITEM_PRICE',
#  'MAX_ITEM_PRICE',
#  'ESTIMATED_ORDER_PLACE_DURATION',
#  'MARKET_ID',
#  'ORDER_PROTOCOL',
#  'TOTAL_ONSHIFT_DASHERS',
#  'TOTAL_BUSY_DASHERS',
#  'TOTAL_OUTSTANDING_ORDERS',
#  'ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION',
#  'DELIVERY_DURATION_SEC']

# %%
# Outliers detecting
detected_outliers= {}
for col in con:

    q1 = np.percentile(df_cleaned[col], 25)
    q3 = np.percentile(df_cleaned[col], 75)

    iqr = q3 - q1 

    minimun = q1 - 1.5 * iqr
    maximum = q3 + 1.5 * iqr

    lower_out = df_cleaned[col] < minimun
    upper_out = df_cleaned[col] > maximum

    outliers = df_cleaned[lower_out | upper_out]

    detected_outliers[col] = {
        "lower": minimun,
        "upper": maximum,
        "ecom": len(outliers),
        "outlier_pct": round(len(outliers)/len(df_cleaned) * 100, 2)
    }

outliers_report = pd.DataFrame(detected_outliers)
outliers_report.T
# Out:
#                                                  lower      upper     ecom  \
# STORE_ID                                     -3732.000  10716.000      0.0
# TOTAL_ITEMS                                     -1.000      7.000   9493.0
# SUBTOTAL                                     -1594.000   6390.000   8949.0
# NUM_DISTINCT_ITEMS                              -2.000      6.000   5872.0
# MIN_ITEM_PRICE                                -676.000   1924.000   4557.0
# MAX_ITEM_PRICE                                 -92.500   2287.500   7660.0
# ESTIMATED_ORDER_PLACE_DURATION                 -41.500    738.500     28.0
# MARKET_ID                                       -1.000      7.000      0.0
# ORDER_PROTOCOL                                  -3.500      8.500      0.0
# TOTAL_ONSHIFT_DASHERS                          -60.500    135.500   1847.0
# TOTAL_BUSY_DASHERS                             -62.125    132.875    602.0
# TOTAL_OUTSTANDING_ORDERS                       -90.000    182.000   6195.0
# ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION   -98.000   1182.000    364.0
# DELIVERY_DURATION_SEC                           98.000   5298.000  11792.0
#
#                                               outlier_pct
# STORE_ID                                             0.00
# TOTAL_ITEMS                                          4.86
# SUBTOTAL                                             4.58
# NUM_DISTINCT_ITEMS                                   3.01
# MIN_ITEM_PRICE                                       2.33
# MAX_ITEM_PRICE                                       3.92
# ESTIMATED_ORDER_PLACE_DURATION                       0.01
# MARKET_ID                                            0.00
# ORDER_PROTOCOL                                       0.00
# TOTAL_ONSHIFT_DASHERS                                0.95
# TOTAL_BUSY_DASHERS                                   0.31
# TOTAL_OUTSTANDING_ORDERS                             3.17
# ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION         0.19
# DELIVERY_DURATION_SEC                                6.03

# %%
# Outliers Handling
def handle_outlier(col):
    global df_outliers
    # 1st quartile - 25%
    q1 = np.percentile(df_cleaned[col],25)
    # 3rd quartile - 75%
    q3 = np.percentile(df_cleaned[col],75)
    # IQR - Inter quartile range
    iqr = q3-q1
    # calculate minimum and maximum to determine outliers
    mini = q1 - (1.5*iqr)
    maxi = q3 + (1.5*iqr)

    lower_index = list(df_cleaned[df_cleaned[col]<mini].index)
    upper_index = list(df_cleaned[df_cleaned[col]>maxi].index)

    all_ = lower_index + upper_index
    df_outliers = df_cleaned.drop(index=all_)
    print("====================================================")
    print(col)
    print(f"Shape before outlier handling is {df_cleaned.shape}")
    print(f"Minimum values present at index {lower_index}")
    print(f"Maximum values present at index {upper_index}")
    print(f"Outliers are handled for {col}")
    print(f"Shape after outlier handling is {df_outliers.shape}")
    print("===============================")
    return df_outliers

# %%
for i in con:
    handle_outlier(i)
# Out:
# ====================================================
# STORE_ID
# Shape before outlier handling is (195402, 17)
# Minimum values present at index []
# Maximum values present at index []
# Outliers are handled for STORE_ID
# Shape after outlier handling is (195402, 17)
# ===============================
# ====================================================
# TOTAL_ITEMS
# Shape before outlier handling is (195402, 17)
# Minimum values present at index []
# Maximum values present at index [37, 59, 122, 136, 165, 180, 193, 242, 246, 258, 283, 352, 382, 391, 458, 460, 486, 506, 532, 536, 558, 560, 576, 628, 634, 638, 659, 678, 696, 719, 795, 798, 800, 814, 967, 975, 982, 990, 1052, 1058, 1064, 1075, 1077, 1084, 1089, 1093, 1096, 1097, 1105, 1209, 1219, 1220, 1222, 1230, 1244, 1284, 1287, 1306, 1342, 1344, 1345, 1346, 1351, 1353, 1355, 1358, 1359, 1360, 1361, 1362, 1368, 1372, 1373, 1375, 1378, 1382, 1384, 1385, 1389, 1486, 1487, 1498, 1509, 1514, 1521, 1524, 1580, 1595, 1607, 1615, 1616, 1661, 1674, 1719, 1728, 1737, 1739, 1746, 1757, 1799, 1811, 1817, 1818, 1820, 1825, 1826, 1827, 1828, 1836, 1840, 1842, 1867, 1868, 1953, 1969, 1970, 2015, 2103, 2163, 2174, 2181, 2182, 2241, 2253, 2256, 2268, 2276, 2280, 2308, 2310, 2316, 2318, 2320, 2322, 2325, 2327, 2333, 2416, 2442, 2446, 2465, 2470, 2608, 2630, 2634, 2701, 2751, 2753, 2762, 2831, 2833, 2834, 2839, 2845, 2846, 2872, 2875, 2886, 2929, 2941, 2950, 2961, 3015, 3049, 3060, 3090, 3093, 3098, 3105, 3146, 3147, 3148, 3178, 3183, 3194, 3199, 3203, 3255, 3256, 3259, 3260, 3261, 3262, 3265, 3266, 3270, 3273, 3279, 3283, 3286, 3287, 3288, 3333, 3336, 3364, 3367, 3386, 3440, 3445, 3452, 3493, 3498, 3513, 3526, 3551, 3566, 3619, 3631, 3633, 3638, 3639, 3647, 3654, 3671, 3721, 3726, 3732, 3734,
# MAX_ITEM_PRICE                                183610.0  1158.026535
# ESTIMATED_ORDER_PLACE_DURATION                183610.0   307.858183
# MARKET_ID                                     183610.0     2.991335
# ORDER_PROTOCOL                                183610.0     2.885638
# TOTAL_ONSHIFT_DASHERS                         183610.0    42.008235
# TOTAL_BUSY_DASHERS                            183610.0    39.074685
# TOTAL_OUTSTANDING_ORDERS                      183610.0    54.184391
# ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION  183610.0   541.894831
# DELIVERY_DURATION_SEC                         183610.0  2741.142013
#
#                                                       std    min     25%  \
# STORE_ID                                      2053.336320    1.0  1686.0
# TOTAL_ITEMS                                      2.661045    1.0     2.0
# SUBTOTAL                                      1799.543548    0.0  1400.0
# NUM_DISTINCT_ITEMS                               1.616960    1.0     1.0
# MIN_ITEM_PRICE                                 519.855731  -86.0   299.0
# MAX_ITEM_PRICE                                 554.525776    0.0   800.0
# ESTIMATED_ORDER_PLACE_DURATION                  89.678686    0.0   251.0
# MARKET_ID                                        1.520131    1.0     2.0
# ORDER_PROTOCOL                                   1.503135    1.0     1.0
# TOTAL_ONSHIFT_DASHERS                           35.502945   -4.0    13.0
# TOTAL_BUSY_DASHERS                              33.019763   -5.0    12.0
# TOTAL_OUTSTANDING_ORDERS                        53.025215   -6.0    13.0
# ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION   218.587524    0.0   379.0
# DELIVERY_DURATION_SEC                          885.833547  101.0  2085.0
#
#                                                  50%     75%      max
# STORE_ID                                      3592.0  5299.0   6987.0
# TOTAL_ITEMS                                      3.0     4.0    411.0
# SUBTOTAL                                      2200.0  3385.0  26800.0
# NUM_DISTINCT_ITEMS                               2.0     3.0     20.0
# MIN_ITEM_PRICE                                 595.0   949.0  14700.0
# MAX_ITEM_PRICE                                1095.0  1395.0  14700.0
# ESTIMATED_ORDER_PLACE_DURATION                 251.0   446.0   1740.0
# MARKET_ID                                        3.0     4.0      6.0
# ORDER_PROTOCOL                                   3.0     4.0      7.0
# TOTAL_ONSHIFT_DASHERS                           34.0    63.0    171.0
# TOTAL_BUSY_DASHERS                              31.0    60.0    154.0
# TOTAL_OUTSTANDING_ORDERS                        37.0    81.0    285.0
# ESTIMATED_STORE_TO_CONSUMER_DRIVING_DURATION   540.0   698.0   1711.0
# DELIVERY_DURATION_SEC                         2623.0  3290.0   5298.0

# %%
df_outliers[cat].describe().T
# Out:
#                          count unique       top   freq
# STORE_PRIMARY_CATEGORY  183610     75  american  18120

# %%
df_outliers[time].describe().T
# Out:
#                        count                       mean  \
# CREATED_AT            183610  0 days 08:35:17.299439028
# ACTUAL_DELIVERY_TIME  183610  0 days 09:20:58.441451990
#
#                                             std              min  \
# CREATED_AT            0 days 08:26:01.809215074  0 days 00:00:01
# ACTUAL_DELIVERY_TIME  0 days 08:23:24.413476073  0 days 00:15:28
#
#                                   25%              50%  \
# CREATED_AT            0 days 02:11:07  0 days 03:38:25
# ACTUAL_DELIVERY_TIME  0 days 03:01:38  0 days 04:28:19
#
#                                          75%              max
# CREATED_AT            0 days 19:25:10.750000  0 days 23:52:55
# ACTUAL_DELIVERY_TIME         0 days 20:08:16  0 days 23:59:59
